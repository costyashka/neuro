# %%
from scipy.cluster.hierarchy import dendrogram, ward
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt

# %%
X,y = make_blobs(n_samples=12)
linkage_array = ward(X)
dendrogram(linkage_array)
# Out:
# {'icoord': [[25.0, 25.0, 35.0, 35.0],
#   [15.0, 15.0, 30.0, 30.0],
#   [5.0, 5.0, 22.5, 22.5],
#   [65.0, 65.0, 75.0, 75.0],
#   [55.0, 55.0, 70.0, 70.0],
#   [45.0, 45.0, 62.5, 62.5],
#   [105.0, 105.0, 115.0, 115.0],
#   [95.0, 95.0, 110.0, 110.0],
#   [85.0, 85.0, 102.5, 102.5],
#   [53.75, 53.75, 93.75, 93.75],
#   [13.75, 13.75, 73.75, 73.75]],
#  'dcoord': [[0.0, 1.360515761478897, 1.360515761478897, 0.0],
#   [0.0, 2.5750629745615945, 2.5750629745615945, 1.360515761478897],
#   [0.0, 3.082315891500462, 3.082315891500462, 2.5750629745615945],
#   [0.0, 0.4639516733259732, 0.4639516733259732, 0.0],
#   [0.0, 2.169378049443475, 2.169378049443475, 0.4639516733259732],
#   [0.0, 2.794726790405426, 2.794726790405426, 2.169378049443475],
#   [0.0, 0.3874782891980279, 0.3874782891980279, 0.0],
#   [0.0, 1.3964655790919995, 1.3964655790919995, 0.3874782891980279],
#   [0.0, 2.8474208110526473, 2.8474208110526473, 1.3964655790919995],
#   [2.794726790405426, 9.14943976442658, 9.14943976442658, 2.8474208110526473],
#   [3.082315891500462, 29.61686579226341, 29.61686579226341, 9.14943976442658]],
#  'ivl': ['4', '8', '2', '3', '9', '1', '0', '11', '10', '6', '5', '7'],
#  'leaves': [4, 8, 2, 3, 9, 1, 0, 11, 10, 6, 5, 7],
#  'color_list': ['C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C0']}

# %%
ax = plt.gca()
bounds = ax.get_xbound()
ax.plot(bounds,[7.25,7.25],'--',c='k')
ax.plot(bounds,[4,4],'--',c='k')
plt.show()
